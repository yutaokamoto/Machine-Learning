# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Colaboratory

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/My Drive"
# Out:
# /content/gdrive/My Drive

# %%
# !pwd
# Out:
# /content/gdrive/My Drive

# %%
# !ls -a
# Out:
#  Colaboratory   .ipynb_checkpoints  'Machine Learning'

# %%
# %cd Machine\ Learning
# Out:
# /content/gdrive/My Drive/Machine Learning

# %%
# !git clone https://github.com/yutaokamoto/Machine-Learning.git "/content/gdrive/My Drive/Machine Learning"
# Out:
# Cloning into '/content/gdrive/My Drive/Machine Learning'...
# warning: You appear to have cloned an empty repository.

# %%
# !ls -a
# Out:
# fastai1_1.ipynb  gitinit.ipynb		 Part2_Music_Generation.ipynb
# .git		 Part1_TensorFlow.ipynb

# %%
# !git remote add origin https://github.com/yutaokamoto/Machine-Learning.git
# Out:
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/yutaokamoto/Machine-Learning.git (fetch)
# origin	https://github.com/yutaokamoto/Machine-Learning.git (push)

# %%
# !git config --global user.email "yutaokamoto1997@gmail.com"
# !git config --global user.name "yutaokamoto"

# %%
# !git add .

# %%
# !git commit -m "new"
# Out:
# [master (root-commit) 998845a] new
#  4 files changed, 4 insertions(+)
#  create mode 100644 Part1_TensorFlow.ipynb
#  create mode 100644 Part2_Music_Generation.ipynb
#  create mode 100644 fastai1_1.ipynb
#  create mode 100644 gitinit.ipynb

# %%
# !git remote set-url origin https://github.com/yutaokamoto/Machine-Learning.git

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
